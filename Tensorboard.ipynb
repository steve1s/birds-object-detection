# %% [markdown]
# # Tensorboard

# %% [markdown]
# ## Faster R-CNN

# %%
PATH_TO_MODEL = "faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"

# %%
# !tensorboard --logdir=/home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/object_detection/training/TF2/training/{PATH_TO_MODEL}/
# Out:
# 2023-06-29 19:43:04.769174: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.6.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
from IPython.display import Image

# %% [markdown]
# # Loss

# %%
Image(filename='/home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/loss.png')

# %% [markdown]
# # LEarning rate

# %%
Image(filename='/home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/learn.png')

# %%
Image(filename='/home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/learn1.png')

# %% [markdown]
# # SSD ResNet50

# %%
PATH_TO_MODEL = "ssd_resnet50_v1_fpn_640x640_coco17_tpu-8"

# %%
# !tensorboard --logdir=/home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/object_detection/training/TF2/training/{PATH_TO_MODEL}/
# Out:
# 2023-06-28 09:52:57.572046: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.6.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
/home/msc1/Desktop/Tensorflow-Object-Detection-API/Base/v1/object_detection/training/TF2/training/
